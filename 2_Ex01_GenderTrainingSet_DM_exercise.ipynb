# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
# ----------------------------------------------
# Disciplina: Modelagem e Mineracao de Dados
# ------------------------------------------
# Master Program - Mathematical Modeling of Information
# -----------------------------------------------------
# Course: Data Mining and Modeling
# --------------------------------
# Professor: Renato Rocha Souza
# -----------------------------

# %% [markdown]
# First Assignment - Dataset Analysis
# -----------------------------------
#
# Gender Training Dataset
# http://www.inf.ed.ac.uk/teaching/courses/dme/html/datasets0405.html

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import pylab as pl
import pandas as pd
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Specifying the path to the files

# %%
datapath = "../datasets/"
dataset1 = "gendertrainingset.csv"

# %% [markdown]
# Loading the dataset
#
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.loadtxt.html

# %%
example_data = np.loadtxt(os.path.join(datapath,dataset1), delimiter=',',skiprows=2)

# %%
def bstats(vec):
    s = {'num_element':len(vec), 'minimo':vec.min(),
         'maximo':vec.max(), 'media':vec.mean(),
         'desvio_padrao':vec.std()}
    return s

# %%
bstats(example_data[:,0])
# Out:
# {'desvio_padrao': 9.6109052529404924,
#  'maximo': 56.0,
#  'media': 38.167544917114569,
#  'minimo': 24.0,
#  'num_element': 189961}

# %%
plt.plot(sorted(example_data[:,0]))
plt.show()

# %%
plt.hist(example_data[:,0], bins=40)
plt.show()

# %%
pd_ex_data = pd.read_csv(os.path.join(datapath,dataset1), sep=',', skiprows=1)
pd_ex_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189961 entries, 0 to 189960
# Data columns (total 15 columns):
# age                                   189961 non-null int64
# destreza                              189961 non-null int64
# genero                                189961 non-null int64
# gsr_low_average                       189961 non-null float64
# heat_flux_high_average                189961 non-null float64
# near_body_temp_average                189961 non-null float64
# pedometer                             189961 non-null int64
# skin_temp_average                     189961 non-null float64
# longitudinal_accelerometer_SAD        189961 non-null float64
# longitudinal_accelerometer_average    189961 non-null float64
# transverse_accelerometer_SAD          189961 non-null float64
# transverse_accelerometer_average      189961 non-null float64
# userID                                189961 non-null int64
# ...

# %%
pd_ex_data.head()
# Out:
#    age  destreza  genero  gsr_low_average  heat_flux_high_average  \
# 0   56         1       1         0.008877               24.081720
# 1   56         1       1         0.017754               22.103062
# 2   56         1       1         0.035508               19.931364
# 3   56         1       1         0.044385               19.352243
# 4   56         1       1         0.053262               20.076143
#
#    near_body_temp_average  pedometer  skin_temp_average  \
# 0               28.430960         24          28.559978
# 1               28.828419         69          28.559978
# 2               29.147713        120          28.825512
# 3               29.371952        105          29.091856
# 4               29.500366         34          29.323360
#
#    longitudinal_accelerometer_SAD  longitudinal_accelerometer_average  \
# 0                       45.107361                            0.950269
# 1                      144.490280                            0.912258
# ...

# %%
pd_ex_data.describe()
# Out:
#                  age       destreza         genero  gsr_low_average  \
# count  189961.000000  189961.000000  189961.000000    189961.000000
# mean       38.167545       0.047462       0.350193         4.778562
# std         9.610931       0.212626       0.477031         4.671155
# min        24.000000       0.000000       0.000000        -0.017754
# 25%        30.000000       0.000000       0.000000         1.260527
# 50%        36.000000       0.000000       0.000000         3.284473
# 75%        48.000000       0.000000       1.000000         6.755361
# max        56.000000       1.000000       1.000000        18.259892
#
#        heat_flux_high_average  near_body_temp_average      pedometer  \
# count           189961.000000           189961.000000  189961.000000
# mean                24.157362               32.100273      19.970304
# std                  9.832585                1.587565      22.252644
# min                -61.917530               16.847130       0.000000
# ...

# %%
pd_ex_data.groupby('genero')[['age','destreza','gsr_low_average']].describe()
# Out:
#                         age       destreza  gsr_low_average
# genero
# 0      count  123438.000000  123438.000000    123438.000000
#        mean       32.844805       0.000000         4.566431
#        std         4.791274       0.000000         4.470143
#        min        24.000000       0.000000        -0.017754
#        25%        30.000000       0.000000         1.278281
#        50%        32.000000       0.000000         3.071426
#        75%        36.000000       0.000000         6.533437
#        max        48.000000       0.000000        18.259892
# 1      count   66523.000000   66523.000000     66523.000000
#        mean       48.044255       0.135532         5.172186
#        std         8.429193       0.342294         4.999122
#        min        34.000000       0.000000        -0.017754
#        25%        35.000000       0.000000         1.198389
#        50%        53.000000       0.000000         3.737197
# ...

# %% [markdown]
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.cov.html
# http://en.wikipedia.org/wiki/Covariance
# http://docs.scipy.org/doc/numpy/reference/generated/numpy.corrcoef.html
# http://en.wikipedia.org/wiki/Correlation_and_dependence

# %%
a = np.array(pd_ex_data['gsr_low_average'])
b= np.array(pd_ex_data['heat_flux_high_average'])

# %%
a
# Out:
# array([ 0.00887695,  0.01775391,  0.03550781, ...,  3.6484277 ,
#         3.604043  ,  3.5152733 ])

# %%
#plt.plot(figsize(10,10))
plt.scatter(a,b, c='b', marker='+')

# %%
pd_ex_data.groupby('userID').describe()
# Out:
#                        age  destreza        genero  gsr_low_average  \
# userID
# 2      count   4547.000000      4547   4547.000000      4547.000000
#        mean      43.000000         0      0.000000         2.019844
#        std        0.000000         0      0.000000         2.585662
#        min       43.000000         0      0.000000         0.008877
#        25%       43.000000         0      0.000000         0.284062
#        50%       43.000000         0      0.000000         0.639141
#        75%       43.000000         0      0.000000         2.170415
#        max       43.000000         0      0.000000         8.805938
# 3      count   5181.000000      5181   5181.000000      5181.000000
#        mean      36.000000         0      0.000000         4.584392
#        std        0.000000         0      0.000000         3.243389
#        min       36.000000         0      0.000000         0.026631
#        25%       36.000000         0      0.000000         2.192607
# ...
