# %% [markdown]
# Mestrado em Modelagem Matematica da Informacao
# ----------------------------------------------
# Disciplina: Modelagem e Mineracao de Dados
# ------------------------------------------
# Master Program - Mathematical Modeling of Information
# -----------------------------------------------------
# Course: Data Mining and Modeling
# --------------------------------
# Professor: Renato Rocha Souza
# -----------------------------
# Aluno: Marcio Maciel Bastos
# ----------------------------
# Exercício 1: Gender Training Set
# --------------------------------

# %% [markdown]
# ###### Description: This data set was made available for the Physiological Data Modeling Contest at ICML 2004. The data was collected from subjects using BodyMedia wearable body monitors while performing their usual activities. These monitors record acceleration, heat flux, galvanic skin response, skin temperature, and near-body temperature. The training data set includes several sessions for each of multiple subjects, with measurements stored each minute during a session. The test data set includes further sessions from the same subjects, as well as sessions recording measurements from new subjects who did not feature in the training data. Each record in the data includes an annotation code giving information about the kind of activity that the subject was performing at that time. Participants in the competition were asked to train classifiers to apply two of these annotation codes to the test data, and also to train a classifier to identify subjects as men or women (this information is given in the training data sequences).

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as ss
import pylab as pl
import pandas as pd
import os
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
datapath = "../datasets/"
dataset1 = "gendertrainingset.csv"

# %%
dados=pd.read_csv(os.path.join(datapath,dataset1), sep=',', skiprows=1)

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 189961 entries, 0 to 189960
# Data columns (total 15 columns):
# age                                   189961 non-null int64
# destreza                              189961 non-null int64
# genero                                189961 non-null int64
# gsr_low_average                       189961 non-null float64
# heat_flux_high_average                189961 non-null float64
# near_body_temp_average                189961 non-null float64
# pedometer                             189961 non-null int64
# skin_temp_average                     189961 non-null float64
# longitudinal_accelerometer_SAD        189961 non-null float64
# longitudinal_accelerometer_average    189961 non-null float64
# transverse_accelerometer_SAD          189961 non-null float64
# transverse_accelerometer_average      189961 non-null float64
# userID                                189961 non-null int64
# ...

# %%
for i in range(72):
    if i in dados['userID']:
        dados['age'][(dados.userID==6)&(dados.age!=dados['age'][(dados.userID==6)].quantile(0.75))]=dados['age'][(dados.userID==6)].quantile(0.75)

# %%
f, ax = plt.subplots(nrows=2, ncols=1, figsize=(12,12), sharex=True, sharey=True)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
ax[0].plot(pl.movavg(dados['near_body_temp_average'],100),color='green')
ax[0].grid(True)
ax[0].set_title('near_body_temp_average')
ax[1].plot(pl.movavg(dados['skin_temp_average'],100),color='brown')
ax[1].grid(True)
ax[1].set_title('skin_temp_average')

# %%
f, ax = plt.subplots(nrows=2, ncols=1, figsize=(12,12), sharex=True, sharey=True)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
ax[0].plot(pl.movavg(dados['gsr_low_average'],100),'b')
ax[0].grid(True)
ax[0].set_title('gsr_low_average')
ax[1].plot(pl.movavg(dados['heat_flux_high_average'],100),color='purple')
ax[1].grid(True)
ax[1].set_title('heat_flux_high_average')
plt.show()

# %%
f, ax = plt.subplots(nrows=2, ncols=1, figsize=(12,12), sharex=True, sharey=True)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
ax[0].plot(pl.movavg(dados['longitudinal_accelerometer_average'],100),color='red')
ax[0].grid(True)
ax[0].set_title('longitudinal_accelerometer_average')
ax[1].plot(pl.movavg(dados['transverse_accelerometer_average'],100),color='purple')
ax[1].grid(True)
ax[1].set_title('transverse_accelerometer_average')

# %%
f, ax = plt.subplots(nrows=3, ncols=1, figsize=(12,12), sharex=True, sharey=True)
plt.setp([a.get_xticklabels() for a in f.axes[:-1]], visible=False)
ax[0].plot(pl.movavg(dados['longitudinal_accelerometer_SAD'],400),color='blue')
ax[0].grid(True)
ax[0].set_title('longitudinal_accelerometer_SAD')
ax[1].plot(pl.movavg(dados['transverse_accelerometer_SAD'],400),color='black')
ax[1].grid(True)
ax[1].set_title('transverse_accelerometer_SAD ')
ax[2].plot(4*pl.movavg(dados['pedometer'],400),color='gray')
ax[2].grid(True)
ax[2].set_title('pedometer')

# %%
plt.plot(figsize(20,5))
plt.plot(pl.movavg(dados['longitudinal_accelerometer_SAD'],400),color='blue',alpha=0.5,label='longitudinal_accelerometer_SAD')
plt.plot(pl.movavg(dados['transverse_accelerometer_SAD'],400),color='purple',alpha=0.5,label='transverse_accelerometer_SAD')
plt.plot(4*pl.movavg(dados['pedometer'],400),color='red',alpha=0.5,label='pedometer')
X=pl.movavg(dados['longitudinal_accelerometer_SAD'],400)-4*pl.movavg(dados['pedometer'],400)
Y=pl.movavg(dados['transverse_accelerometer_SAD'],400)-4*pl.movavg(dados['pedometer'],400)                                                                 
plt.legend()
plt.grid(True)

# %%
c=pl.correlate(pl.movavg(dados['transverse_accelerometer_SAD'],400),4*pl.movavg(dados['pedometer'],400),'same')
plt.plot(c)

# %%
c=pl.correlate(pl.movavg(dados['longitudinal_accelerometer_SAD'],400),4*pl.movavg(dados['pedometer'],400),'same')
plt.plot(c)

# %%
a=pl.correlate(pl.correlate(pl.movavg(dados['transverse_accelerometer_SAD'],400),4*pl.movavg(dados['pedometer'],400),'same'),pl.correlate(pl.movavg(dados['longitudinal_accelerometer_SAD'],400),4*pl.movavg(dados['pedometer'],400),'same'),'same')
plt.plot(a)

# %%
plt.plot(figsize(13,13))
plt.plot(pl.movavg(dados['heat_flux_high_average'],100),'k')
plt.plot(pl.movavg(dados['near_body_temp_average'],50),'g')
plt.plot(dados['age'],'bo')
plt.legend(['age','near_body_temp_average','heat_flux_high_average'])

# %%
plt.plot(figsize(8,8))
plt.plot(dados['userID'],label='userID')
plt.plot(dados['age'],label='age')
plt.legend()

# %%
plt.plot(figsize(13,13))
plt.plot(2*dados['gsr_low_average'],'k')
plt.plot(pl.movavg(dados['heat_flux_high_average'],50),'g',alpha=0.5)
plt.plot(dados['userID'],'b')
